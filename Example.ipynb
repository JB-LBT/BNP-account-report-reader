# %%
from src import *

# %%
process_folder(dest_file="Output//Example.xlsx", verbose = True)
# Out:
# Processing file 1/5
# Started parsing the file under job_id bc1ae73f-4bc1-44d7-8d76-0e55d5afd42b
# Execution time of add_operations: 3 seconds
# Total budget for 12 2023: 305. Remaining budget: -804.47
# Processing file 2/5
# Started parsing the file under job_id a9fec4fa-b928-43b5-9923-9f80f9341445
# Execution time of add_operations: 19 seconds
# Total budget for 1 2024: 305. Remaining budget: -37657.8
# Processing file 3/5
# Started parsing the file under job_id b23d280a-5205-435d-8940-ba4aa9e44556
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 process_folder(dest_file="processed_pdf2.xlsx", verbose = True)
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:780, in process_folder(folder, dest_file, **kwargs)
#     778 def process_folder(folder = "Data", dest_file = None, **kwargs):
#     779     files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".pdf")]
# --> 780     process_files(files, dest_file, **kwargs)
#     781     return None
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:773, in process_files(files, dest_file, **kwargs)
#     771         file_to_excel(file, **kwargs)
#     772     else:
# --> 773         file_to_excel(file, dest_file, **kwargs)
#     775 print("All files processed")
#     776 return None
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:759, in file_to_excel(file, excel_file, **kwargs)
#     757 def file_to_excel(file, excel_file, **kwargs):
#     758     ms = Monthly_Summary(file, **kwargs)
# --> 759     ms.add_operations()
#     760     ms.add_monthly_budget()
#     761     ms.to_excel(excel_file)
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:55, in timeit.<locals>.wrapper(*args, **kwargs)
#      52 @wraps(func)
#      53 def wrapper(*args, **kwargs):
#      54     start = datetime.now()
# ---> 55     result = func(*args, **kwargs)
#      56     end = datetime.now()
#      57     execution_time = end - start
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:205, in Monthly_Summary.add_operations(self, **kwargs)
#     202     self.operations = pd.DataFrame(columns = ["Date", "Description", "Operation Date", "Debit (€)", "Credit (€)", "Category"])
#     204 try:
# --> 205     documents = self._load_pdf()
#     206     self.logger.log(f"PDF {self.pdf} loaded")
#     207 except Exception as e:
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\src.py:744, in Monthly_Summary._load_pdf(self)
#     736 parser = LlamaParse( # can also be set in your env as LLAMA_CLOUD_API_KEY
#     737     result_type="markdown",  # "markdown" and "text" are available
#     738     num_workers=4,  # if multiple files passed, split in `num_workers` API calls
#     739     verbose=True,
#     740     language="en",  # Optionally you can define a language, default=en
#     741 )
#     743 # sync
# --> 744 documents = parser.load_data(self.pdf)
#     745 return documents
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\.venv\lib\site-packages\llama_parse\base.py:379, in LlamaParse.load_data(self, file_path, extra_info)
#     377 """Load data from the input path."""
#     378 try:
# --> 379     return asyncio.run(self.aload_data(file_path, extra_info))
#     380 except RuntimeError as e:
#     381     if nest_asyncio_err in str(e):
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\.venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\.venv\lib\site-packages\nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File d:\Jean-Baptiste\Documents\Cours\Account_summary_reader\.venv\lib\site-packages\nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
from llama_parse import LlamaParse
parser = LlamaParse( # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="text",  # "markdown" and "text" are available
    num_workers=4,  # if multiple files passed, split in `num_workers` API calls
    verbose=True,
    language="en",  # Optionally you can define a language, default=en
)

# sync
documents = parser.load_data("Data\RLV_CHQ_300040085400001025859_20240122.pdf")

documents
# Out:
# Started parsing the file under job_id b4ad7ea1-9da6-436f-919c-e20052668e40
# [Document(id_='834efe58-8cf9-4595-8a5f-a4451ca7d8ef', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="               BVb BVKIBV2\n                                                                                  RELEVE DE COMPTE CHEQUES21 janvier 2024du 21 décembre 2023 au                                                               P. 1/2\n\n   PARIS-MONTPARNAS                                                                                                                            03286 02601\n   Tél. Agence : 01 44 10 93 50 (numéro non surtaxé)\n   Tél. : 3477 (Service gratuit + prix appel)\n\n   RIB : 30004 00854 00001025859 87                                                                                                            MR JEAN BAPTISTE LABIT\n   IBAN : FR76 3000 4008 5400 0010 2585 987                                                                                                    3 ALLEE DU COLOMBIER\n   BIC : BNPAFRPPXXX                                                                                                                           78230 LE PECQ\n\n                              Vous trouverez, annexées à votre relevé ou sur l'appli Mes comptes et la\n                              messagerie du site mabanque.bnpparibas (pour les clients des agences) ou\n                              mabanqueprivee.bnpparibas (pour les clients des centres Banque Privée) :l'information annuelle relative à la réglementation sur le\n                            Fonds de Garantie des Dépôts et de Résolution, ainsi que les modificationsde votre convention de compte et de ses annexes au 1er avril 2024.\n                                 enVous disposez d'un délai de 2 mois pour refuser ces modifications\n                                      résiliant votre convention de compte et/ou votre contrat Servicesen ligne, sans frais, avant leur entrée en vigueur.\n                                                        L'absence de refus de votre part vaut acceptation.\n\n                            Les sommes déposées sur ce compte sont éligibles à la garantie des dépôts du Fonds de Garantie des\n                            Dépôts et de Résolution, sauf exclusions réglementaires en raison de la nature des personnes et/ou des\n                            dépôts.\n                            www.garantiedesdepots.fr\n\n                                                                                                                                                                                   Monnaie du compte : Euro\n       Date             Nature des opérations                                                                              Valeur                                         Débit                             Crédit\n                        SOLDE CREDITEUR AU 21.12.2023                                                                                                                                                 29 421,76\n       26.12            FACTURE(S) CARTE 4974XXXXXXXX7505LE ROI                                                              26.12                                           4,99\n                        DU 221223 CARREFOUR MARKE MARLY\n       02.01            DU 010124 COFIROUTE, 2 PA NANTERRE CEDE                                                              02.01                                         29,50\n       02.01            DU 301223 MERCURE                               AMIENS                                               02.01                                         67,50\n       02.01            DU 010124 TOTAL                             COIGNIERES                                               02.01                                         67,78\n       03.01            *COMMISSIONS - FORFAIT OPTION TRAVEL                                                                 03.01                                           5,00 ...
#  Document(id_='ae5860f8-e154-40e8-bf10-04b830bb74a8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="                                                                  RELEVE DE COMPTE CHEQUES21 janvier 2024du 21 décembre 2023 au                                             P. 2/2\n\nPARIS-MONTPARNAS                                                                                                MR JEAN BAPTISTE LABIT\nRIB : 30004 00854 00001025859 87\n\n    Date          Nature des opérations                                                            Valeur                                Débit                            Crédit\n    08.01         DU 060124 E.LECLERC                                                               08.01                                 64,07\n                  FRA      64,07EUR\n    08.01         VIR SEPA RECU /DE STRIPE /MOTIF VIREMENT                                          08.01                                                                 790,00\n                  SHERPAS /REF\n                  VIREMENT-JJ28PZSPQTEOZFEVOODSP5BH4B\n    08.01         VIR ETRANGER EMIS /BEN 1/COLUMBINE                                                08.01                             1 109,47\n                  MACHER/BIC BNPAUS3N BNP PARIBAS SA/REF\n                  ZZ1FFRC381LUXEQ4P /MMO EUR 1109,47/EXCH\n                  1.0816/VERS ETATS UNIS/ACH/UDN\n    09.01         FACTURE(S) CARTE 4974XXXXXXXX7505                                                 09.01                                 17,10\n                  DU 060124 SAPN 0501-0701 GRAND COURONN\n    10.01         DU 090124 RATP                     PARIS                                          10.01                                 30,75\n    11.01         DU 100124 AUCHAN VELIZY VELIZY VILLAC                                             11.01                                 11,85\n    11.01         DU 100124 JULES                    VELIZY 259/                                    11.01                                 58,18\n    12.01         DU 110124 LA TSARINE PELM PARIS 01                                                12.01                                 18,50\n    15.01         DU 130124 DE NEUVILLE                   SAINT GERMAI                              15.01                                 31,80\n    15.01         VIRT CPTE A CPTE EMIS SUR LE                                                      16.01                                 45,00\n                  PEL30004033640007601112967\n    16.01         FACTURE(S) CARTE 4974XXXXXXXX7505                                                 16.01                                 18,00\n                  DU 150124 ORLY SUD MULTI ORLY AEROGARE\n    17.01         DU 160124 URSSAF IDF                   ST DENIS                                   17.01                                284,00\n                  TOTAL DES OPERATIONS                                                                                                1 904,88                            790,00\n                  SOLDE CREDITEUR AU 21.01.2024                                                                                                                       28 306,88\n    * Commissions sur services et opérations bancaires. Total : +5,00\n\n     Montant de votre autorisation de débit en compte au 21.01.2024 : 400,00 euros au taux nominal de 12,28 %, soit un\n     TAEG de 16,7 % (le TAEG effectif résultera de l'utilisation de débit en compte dans la limite du taux de l'usure et\n     sera communiqué lors de l'arrêté trimestriel).\n\n                  Rappel : votre numéro client est le :                                        3868009404\n                  Il vous permet de gérer vos comptes et effectuer vos opérations courantes\n                  auprès du Centre de Relations Clients au                                             3477, sur internet Comptes.(service gratuit\ ...

# %%
with open("test.txt", "w") as f:
    f.write(documents[0].text)

# %%
documents
# Out:
# [Document(id_='29feb375-3bb3-4c05-8201-ebc5e144c2b7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="# RELEVE DE COMPTE CHEQUES21 janvier 2024du 21 décembre 2023 au\n\n|PARIS-MONTPARNAS|03286 02601|\n|---|---|\n|Tél. Agence : 01 44 10 93 50 (numéro non surtaxé)|Tél. : 3477 (Service gratuit + prix appel)|\n|RIB : 30004 00854 00001025859 87|MR JEAN BAPTISTE LABIT|\n|IBAN : FR76 3000 4008 5400 0010 2585 987|3 ALLEE DU COLOMBIER|\n|BIC : BNPAFRPPXXX|78230 LE PECQ|\n\nVous trouverez, annexées à votre relevé ou sur l'appli Mes comptes et la messagerie du site mabanque.bnpparibas (pour les clients des agences) ou mabanqueprivee.bnpparibas (pour les clients des centres Banque Privée) : l'information annuelle relative à la réglementation sur le Fonds de Garantie des Dépôts et de Résolution, ainsi que les modifications de votre convention de compte et de ses annexes au 1er avril 2024.\n\nVous disposez d'un délai de 2 mois pour refuser ces modifications résiliant votre convention de compte et/ou votre contrat Services en ligne, sans frais, avant leur entrée en vigueur.\n\nL'absence de refus de votre part vaut acceptation.\n\nLes sommes déposées sur ce compte sont éligibles à la garantie des dépôts du Fonds de Garantie des Dépôts et de Résolution, sauf exclusions réglementaires en raison de la nature des personnes et/ou des dépôts.\n\nwww.garantiedesdepots.fr\n\nMonnaie du compte : Euro\n\n|Date|Nature des opérations|Valeur|Débit|Crédit|\n|---|---|---|---|---|\n|26.12|FACTURE(S) CARTE 4974XXXXXXXX7505LE ROI DU 221223 CARREFOUR MARKE MARLY|26.12| |4,99|\n|02.01|DU 010124 COFIROUTE, 2 PA NANTERRE CEDE|02.01| |29,50|\n|02.01|DU 301223 MERCURE AMIENS|02.01| |67,50|\n|02.01|DU 010124 TOTAL COIGNIERES|02.01| |67,78|\n|03.01|*COMMISSIONS - FORFAIT OPTION TRAVEL CARTE N 4974XXXXXXXX7505 DU 011223 AU 311223|03.01| |5,00|\n|04.01|FACTURE(S) CARTE 4974XXXXXXXX7505 DU 030124 LES Z EBS ST JACUT DE L|04.01| |9,24|\n|04.01|ECHEANCE PRET 03364 60051234 (CAPITAL DU 75000,00 EUR)|04.01| |26,25|\n|05.01|FACTURE(S) CARTE 4974XXXXXXXX7505 DU 040124 EFFIA ST MALO|05.01| |3,90|\n|08.01|DU 060124 LYDIA*LYDIA PARIS|08.01| |2,00|\n\nBNP PARIBAS SA au capital de 2 294 954 818 ¤ - Siège social : 16 bd des Italiens, 75009 Paris - RCS Paris n° 662 042 449 - Id. CE FR76 662042449 - ORIAS n° 07 022 735 402232572934\n\n3477 (service gratuit + prix appel) - mabanque.bnpparibas - Réclamations/Exécution du contrat : Conseiller en agence (ligne directe n° non surtaxé)", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='595c77e9-979d-4b86-82da-6b39ba67915c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="# RELEVE DE COMPTE CHEQUES\n\n|Date|Nature des opérations|Valeur|Débit|Crédit|\n|---|---|---|---|---|\n|08.01|DU 060124 E.LECLERC FRA 64,07EUR|08.01| |64,07|\n|08.01|VIR SEPA RECU /DE STRIPE /MOTIF VIREMENT SHERPAS /REF VIREMENT-JJ28PZSPQTEOZFEVOODSP5BH4B|08.01| |790,00|\n|08.01|VIR ETRANGER EMIS /BEN 1/COLUMBINE MACHER/BIC BNPAUS3N BNP PARIBAS SA/REF ZZ1FFRC381LUXEQ4P /MMO EUR 1109,47/EXCH 1.0816/VERS ETATS UNIS/ACH/UDN|08.01|1 109,47| |\n|09.01|FACTURE(S) CARTE 4974XXXXXXXX7505 DU 060124 SAPN 0501-0701 GRAND COURONN|09.01| |17,10|\n|10.01|DU 090124 RATP PARIS|10.01| |30,75|\n|11.01|DU 100124 AUCHAN VELIZY VELIZY VILLAC|11.01| |11,85|\n|11.01|DU 100124 JULES VELIZY 259/|11.01| |58,18|\n|12.01|DU 110124 LA TSARINE PELM PARIS 01|12.01| |18,50|\n|15.01|DU 130124 DE NEUVILLE SAINT GERMAI|15.01| |31,80|\n|15.01|VIRT CPTE A CPTE EMIS SUR LE PEL30004033640007601112967|16.01| |45,00|\n|16.01|FACTURE(S) CARTE 4974XXXXXXXX7505 DU 150124 ORLY SUD MULTI ORLY AEROGARE|16.01| |18,00|\n|17.01|DU 160124 URSSAF IDF ST DENIS|17.01| |284,00|\n\nTotal des opérations: Débit 1 904,88 Crédit 790,00\n\nSOLDE CREDITEUR AU 21.01.2024: 28 306,88\n\n* Commissions sur services et opérations bancaires. Total : +5,00\n\nMontant de votre autorisation de débit en compte au 21.01.2024 : 400,00 euros au taux nominal de 12,28 %, soit un TAEG de 16,7 % (le TAEG effectif résultera de l'utilisation de débit en compte dans la limite du taux de l'usure et sera communiqué lors de l'arrêté trimestriel).\n\nRappel : votre numéro client est le : 3868009404. Il vous permet de gérer vos comptes et effectuer vos opérations courantes auprès du Centre de Relations Clients au 3477, sur internet Comptes (service gratuit + prix d'appel) et complété de votre code secret mabanque.bnpparibas, ou sur votre mobile avec l'application Mes. Pour obtenir votre code secret, contactez votre conseiller.\n\nVotre satisfaction est notre priorité. Toutefois, si vous souhaitez faire une réclamation: Adressez-vous à votre interlocuteur habituel, votre Conseiller ou votre équipe de Conseillers, de vive voix, par écrit ou via le formulaire en ligne accessible sur notre site ou sur votre application mobile. Vous pouvez aussi contacter le Service Client (coordonnées en en-tête du courrier).\n\nSi vous n'obtenez pas satisfaction, contactez par écrit ou via le formulaire en ligne le Responsable Réclamations Clients dont dépend votre agence.\n\nSi vous êtes en désaccord avec la réponse apportée, ou en l'absence de réponse de la Banque dans un délai de 2 mois, vous pouvez alors saisir gratuitement et par écrit l'un des Médiateurs, selon son domaine de compétence. Le Médiateur est le dernier recours amiable avant d'entreprendre une démarche judiciaire.\n\nCoordonnées disponibles en agence, sur le site Internet ou l'application Mes comptes.\n\nDélai ramené à 15 jours ouvrables pour les litiges portant sur un service de paiement (opération de virement, de prélèvement ou effectuée par carte bancaire) ou 35 jours ouvrables dans certains cas exceptionnels.", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]
